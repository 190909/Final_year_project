# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.densenet import DenseNet169
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
train_data_dir = 'C:/Users/91830/OneDrive/Desktop/Project_dataset/Train'
val_data_dir = 'C:/Users/91830/OneDrive/Desktop/Project_dataset/Validation'

# %%
img_size = 224
batch_size = 32

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                    target_size=(img_size, img_size),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

val_generator = val_datagen.flow_from_directory(val_data_dir,
                                                target_size=(img_size, img_size),
                                                batch_size=batch_size,
                                                class_mode='categorical')
# Out:
# Found 9871 images belonging to 2 classes.
# Found 1067 images belonging to 2 classes.

# %%
model=tf.keras.models.load_model('C:/Users/91830/OneDrive/Desktop/Project_dataset/Models/Densenet169.h5')

# %%
import cv2
import os

video_path = 'C:/Users/91830/OneDrive/Desktop/constant.mp4'
output_dir = 'C:/Users/91830/OneDrive/Desktop/frames'

cap = cv2.VideoCapture(video_path)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

for i in range(frame_count):
    ret, frame = cap.read()
    if not ret:
        break
    frame_name = f"frame_{i}.jpg"
    frame_path = os.path.join(output_dir, frame_name)
    cv2.imwrite(frame_path, frame)

# %%
import numpy as np
from tensorflow.keras.applications.densenet import DenseNet201, preprocess_input

for i in range(frame_count):
    frame_name = f"frame_{i}.jpg"
    frame_path = os.path.join(output_dir, frame_name)
    img = cv2.imread(frame_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    img = preprocess_input(img)
    img = np.expand_dims(img, axis=0)


    prediction = model.predict(img)
if prediction[0][0] > prediction[0][1]:
    result="Fire"
    print('Fire Detected')
else:
    result="No fire"
    print('No Fire Detected')
    # preds = model.predict(img)
    # # Do something with the predictions, e.g. print the top 5 classes
    # top_classes = np.argsort(preds[0])[::-1][:5]
    # print(f"Frame {i}: Top classes: {top_classes}")
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 114ms/step
# Fire Detected

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

if result=="Fire":
    cap = cv2.VideoCapture('C:/Users/91830/OneDrive/Desktop/spreading.mp4')

    interval = 10

    intensity_values = []




    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter('fire_intensity.mp4', fourcc, 20.0, (640, 480))

    # Get the dimensions of the frame
    height, width, channels = frame.shape
    # Calculate the total number of pixels in the frame
    num_pixels = height * width

    print("Total number of pixels in the frames of the video:", num_pixels)

    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret == False:
            break
        if cap.get(1) % interval == 0:
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            ret, thresh = cv2.threshold(gray, 50, 255, cv2.THRESH_BINARY)
            fire_pixels = np.count_nonzero(thresh)
            intensity_values.append(fire_pixels)
            
            print("Number of pixels containing fire       :", fire_pixels)
            intensity=fire_pixels/num_pixels
            print("The intensity of fire in the frame:              ",intensity)
            
            
            out.write(cv2.putText(frame, f'Fire Intensity: {intensity:.2f}', (10, 50), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA))
            # Display the frame
            cv2.imshow('frame', frame)
        
    overall_frames=sum(intensity_values)/len(intensity_values)
    overall_intensity= overall_frames/num_pixels


    print("The overall intensity throughout the video is:    " ,overall_intensity)
# Out:
# Total number of pixels in the frames of the video: 921600
# Number of pixels containing fire       : 154852
# The intensity of fire in the frame:               0.1680251736111111
# Number of pixels containing fire       : 158084
# The intensity of fire in the frame:               0.17153211805555554
# Number of pixels containing fire       : 145508
# The intensity of fire in the frame:               0.15788628472222221
# Number of pixels containing fire       : 154831
# The intensity of fire in the frame:               0.16800238715277777
# Number of pixels containing fire       : 157763
# The intensity of fire in the frame:               0.1711838107638889
# Number of pixels containing fire       : 144368
# The intensity of fire in the frame:               0.15664930555555556
# Number of pixels containing fire       : 142266
# The intensity of fire in the frame:               0.15436848958333332
# Number of pixels containing fire       : 154699
# The intensity of fire in the frame:               0.16785915798611112
# Number of pixels containing fire       : 159331
# The intensity of fire in the frame:               0.17288519965277777
# Number of pixels containing fire       : 150817
# The intensity of fire in the frame:               0.16364691840277779
# Number of pixels containing fire       : 157992
# The intensity of fire in the frame:               0.17143229166666665
# Number of pixels containing fire       : 154568
# The intensity of fire in the frame:               0.16771701388888888
# Number of pixels containing fire       : 161816
# The intensity of fire in the frame:               0.17558159722222222
# Number of pixels containing fire       : 159177
# The intensity of fire in the frame:               0.17271809895833334
# Number of pixels containing fire       : 169980
# The intensity of fire in the frame:               0.18444010416666667
# Number of pixels containing fire       : 168788
# The intensity of fire in the frame:               0.1831467013888889
# Number of pixels containing fire       : 165358
# The intensity of fire in the frame:               0.17942491319444445
# Number of pixels containing fire       : 163467
# The intensity of fire in the frame:               0.177373046875
# Number of pixels containing fire       : 158154
# The intensity of fire in the frame:               0.17160807291666666
# Number of pixels containing fire       : 150582
# The intensity of fire in the frame:               0.16339192708333333
# Number of pixels containing fire       : 151646
# The intensity of fire in the frame:               0.16454644097222224
# Number of pixels containing fire       : 158734
# The intensity of fire in the frame:               0.17223741319444444
# Number of pixels containing fire       : 167540
# The intensity of fire in the frame:               0.18179253472222223
# Number of pixels containing fire       : 170807
# The intensity of fire in the frame:               0.18533745659722223
# Number of pixels containing fire       : 192304
# The intensity of fire in the frame:               0.20866319444444445
# Number of pixels containing fire       : 193095
# The intensity of fire in the frame:               0.209521484375
# Number of pixels containing fire       : 192351
# The intensity of fire in the frame:               0.20871419270833333
# Number of pixels containing fire       : 194755
# The intensity of fire in the frame:               0.21132269965277778
# Number of pixels containing fire       : 202314
# The intensity of fire in the frame:               0.21952473958333332
# Number of pixels containing fire       : 194664
# The intensity of fire in the frame:               0.21122395833333332
# Number of pixels containing fire       : 187674
# The intensity of fire in the frame:               0.20363932291666667
# Number of pixels containing fire       : 189898
# The intensity of fire in the frame:               0.2060525173611111
# Number of pixels containing fire       : 182708
# The intensity of fire in the frame:               0.19825086805555556
# Number of pixels containing fire       : 189385
# The intensity of fire in the frame:               0.2054958767361111
# Number of pixels containing fire       : 178608
# The intensity of fire in the frame:               0.19380208333333335
# Number of pixels containing fire       : 182732
# The intensity of fire in the frame:               0.19827690972222223
# Number of pixels containing fire       : 187493
# The intensity of fire in the frame:               0.20344292534722222
# Number of pixels containing fire       : 184557
# The intensity of fire in the frame:               0.20025716145833333
# Number of pixels containing fire       : 173094
# The intensity of fire in the frame:               0.18781901041666665
# Number of pixels containing fire       : 165966
# The intensity of fire in the frame:               0.18008463541666667
# Number of pixels containing fire       : 145238
# The intensity of fire in the frame:               0.15759331597222223
# Number of pixels containing fire       : 150373
# The intensity of fire in the frame:               0.16316514756944445
# Number of pixels containing fire       : 153252
# The intensity of fire in the frame:               0.1662890625
# The overall intensity throughout the video is:     0.1822308270752584
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

if result=="Fire":
    cap = cv2.VideoCapture('C:/Users/91830/OneDrive/Desktop/Fire_1.mp4')

    interval = 10

    intensity_values = []




    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter('fire_intensity.mp4', fourcc, 20.0, (640, 480))

    # Get the dimensions of the frame
    height, width, channels = frame.shape
    # Calculate the total number of pixels in the frame
    num_pixels = height * width

    print("Total number of pixels in the frames of the video:", num_pixels)

    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret == False:
            break
        if cap.get(1) % interval == 0:
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            ret, thresh = cv2.threshold(gray, 50, 255, cv2.THRESH_BINARY)
            fire_pixels = np.count_nonzero(thresh)
            intensity_values.append(fire_pixels)
            
            print("Number of pixels containing fire       :", fire_pixels)
            intensity=fire_pixels/num_pixels
            print("The intensity of fire in the frame:              ",intensity)
            
            
            out.write(cv2.putText(frame, f'Fire Intensity: {intensity:.2f}', (10, 50), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA))
            # Display the frame
            cv2.imshow('frame', frame)
        
    overall_frames=sum(intensity_values)/len(intensity_values)
    overall_intensity= overall_frames/num_pixels


    print("The overall intensity throughout the video is:    " ,overall_intensity)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 5 if result=="Fire":
#       6     cap = cv2.VideoCapture('C:/Users/91830/OneDrive/Desktop/Fire_1.mp4')
#       8     interval = 10
#
# NameError: name 'result' is not defined

# %%
import cv2
import numpy as np

# load the video
cap = cv2.VideoCapture('C:/Users/91830/OneDrive/Desktop/spreading.mp4')

# initialize variables
area_values = []
frame_count = 0

# loop over the frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # increment frame count
    frame_count += 1
    
    # process every 10 frames
    if frame_count % 10 == 0:
        # preprocess the frame

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        blur = cv2.GaussianBlur(gray, (3, 3), 0)

        # detect the fire region
        fire_region = cv2.threshold(blur, 200, 255, cv2.THRESH_BINARY)[1]
        fire_region = cv2.erode(fire_region, None, iterations=2)
        fire_region = cv2.dilate(fire_region, None, iterations=4)
        contours, hierarchy = cv2.findContours(fire_region, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # calculate the area of the fire
        if len(contours) > 0:
            c = max(contours, key=cv2.contourArea)
            area = cv2.contourArea(c)
            area_values.append(area)
        else:
            area_values.append(0)

# calculate the percentage change in the area of fire over the 10-frame interval
area_diff = np.diff(area_values)
percent_change = (area_diff / area_values[:-1]) * 100

 # determine if the fire is spreading, decreasing or no fire
if percent_change[-1] > 50:
    status="spreading"
    print("The fire is spreading.")
elif percent_change[-1] < -50:
    print("The fire is decreasing.")
    status="The fire is decreasing"
elif abs(percent_change[-1]) < 10:
        print("The fire is constant.")
        status="The fire is constant"
else:
    print("No fire detected.")

# calculate the rate of change in the area of fire over the 10-frame interval
rate_of_change = area_diff / np.mean(area_values[:-1])
print(f"The rate of change in the area of fire is {rate_of_change} per 10 frames.")
# Out:
# The fire is spreading.
# The rate of change in the area of fire is [-0.04827016  0.03937445  0.10004028 -0.09741531  0.32170387  0.14247719
#  -0.29180845 -0.10689435  0.167706    0.23420508  0.38543215  0.61176234
#  -0.16887265  0.01604144 -0.84188414  4.46535465 -2.81731504 -0.64486604
#  -0.8230719   0.15735198 -0.19541395  0.74607297 -0.55649227  1.02621491
#   0.23974667 -1.21783725 -0.0936237   0.28626686  0.13474813  0.61978306
#  -1.1565881   0.0791864  -0.58872099  0.58026277  0.31018319 -0.38761962
#   0.91013319 -1.43731337  0.20620547  1.0899432  -1.27296149  0.42276496] per 10 frames.

# %%
from twilio.rest import Client

# Your Account SID and Auth Token from twilio.com/console
account_sid = 'AC613c9e2d1f380999dd470fe5a50620f6'
auth_token = 'c0342910796e9b3e4e28ddca694da106'

if status =="spreading":
    client = Client(account_sid, auth_token)
    message = client.messages \
                    .create(
                        body="Alert! Fire detected in your forest area and its starting to spread..!! Take necessary actions!!!!!!!",
                        from_='+15855977296',
                        to='+918300661982'
                    )

    print(message.sid)
# Out:
# SM9ad52451d8f41ccf28387e005c95f590

# %%
from twilio.rest import Client

# Your Twilio account information
account_sid = 'AC613c9e2d1f380999dd470fe5a50620f6'
auth_token = 'c0342910796e9b3e4e28ddca694da106'
twilio_number = '+15855977296'
# The phone number to send the message to
to_number = '+918300661982'  # replace with the phone number you want to send the message to

# Check the status and send a message if spreading
if status == "spreading":
    client = Client(account_sid, auth_token)
    message = client.messages.create(
        to=to_number,
        from_=twilio_number,
        body="The status is spreading!"
    )
    print("Message sent successfully.")
else:
    print("No message sent.")
# Out:
# No message sent.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Plot the graph
# ----> 2 plt.plot(frame, intensity)
#       3 plt.xlabel('Frame Number')
#       4 plt.ylabel('Intensity of Fire')
#
# NameError: name 'intensity' is not defined

# %%
import matplotib
